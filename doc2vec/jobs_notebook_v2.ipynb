# %%
import string;
from gensim.models import doc2vec
import numpy as np
import nltk

# We import sklearn.
import sklearn
from sklearn.manifold import TSNE
from sklearn.datasets import load_digits
from sklearn.preprocessing import scale

# Random state.
RS = 30145621

# We'll use matplotlib for graphics.
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
import matplotlib
# %matplotlib inline

# %%
docs = []
titles = []
locations = []
lines = ''
title = ''
location = ''

# %%
with open('unique.txt', 'r') as rf:
    for line in rf:
        if location == '':
            location = line[:-1]
            locations.append(location)
        if title == '':
            title = line[:-1]
            titles.append(title)
            location = ''
        if line == 'zzz\n':
            docs.append(lines)
            lines = ''
            title = ''
            location = ''
        else:
            lines = lines+line

# %%
d, indices, counts = np.unique(docs, return_index=True, return_counts=True)
print(len(d))
print(len(titles))
# Out:
# 14177
# 14177

# %%
"""write out unique jobs to new file"""
with open('U.txt', 'w') as wf:
    for i in indices:
        wf.write(docs[i])
        wf.write('zzz\n')

# %%
def tokenize_jobs(documents):
    """converts job listings to genism tagged documents"""
    tokens = []
    for i in range(len(documents)-1):
        tokenized = [x.lower() for x in nltk.word_tokenize(documents[i], language='english')]
        tokens.append(tokenized)
    return tokens
    

tokens = tokenize_jobs(d)
print(len(tokens))
# Out:
# 14176

# %%
def create_tagged_objects(tokens):
    """Convers tokens to genism tagged documents"""
    tagged_docs = []
    for i in range(len(tokens) - 1):
        tagged_doc = doc2vec.TaggedDocument(words=tokens[i], tags=[i])
        tagged_docs.append(tagged_doc)
    return tagged_docs


tagged_docs = create_tagged_objects(tokens)

# %%
import random

model = doc2vec.Doc2Vec(alpha=0.05, min_alpha=0.05, vector_size=100, window=8, min_count=5, workers=4)


print('Building vocab')
model.build_vocab(tagged_docs)
print('Vocab length: ' + str(len(model.wv.vocab)))

len(model.docvecs)
epochs = 20
factor = 0.9
for epoch in range(epochs):
    # train epoch by epoch
    print('Training epoch %d' % epoch)
    random.shuffle(tagged_docs)
    model.train(tagged_docs, total_examples=model.corpus_count, epochs=model.epochs)
    model.alpha *= factor  # decrease the learning rate
    model.min_alpha = model.alpha  # fix the learning rate, no decay
# Out:
# Building vocab
# Vocab length: 23655
# Training epoch 0
# Training epoch 1
# Training epoch 2
# Training epoch 3
# Training epoch 4
# Training epoch 5
# Training epoch 6
# Training epoch 7
# Training epoch 8
# Training epoch 9
# Training epoch 10
# Training epoch 11
# Training epoch 12
# Training epoch 13
# Training epoch 14
# Training epoch 15
# Training epoch 16
# Training epoch 17
# Training epoch 18
# Training epoch 19

# %%
model.docvecs[1]
# Out:
# array([-0.6737089 , -0.97660583, -0.15252489,  0.70468867, -2.1560898 ,
#        -0.5723263 ,  3.4865632 ,  1.0154489 ,  3.1887832 ,  1.4245416 ,
#         0.3898841 ,  2.2268085 , -1.9803516 , -1.0917691 ,  0.7697824 ,
#         1.8470757 ,  1.2235131 , -0.8030839 ,  1.421041  ,  1.5525411 ,
#         1.117808  , -0.04822988,  1.0359918 , -1.5036613 ,  1.6036965 ,
#         0.6129022 , -2.3317418 ,  3.5032973 ,  1.4852017 , -2.0683799 ,
#        -1.4027038 , -1.4041681 , -1.9004871 ,  1.9917197 ,  1.9814638 ,
#        -0.21640256, -0.18700883, -0.7711888 , -2.8229933 , -0.07496693,
#         0.18056065,  0.43756518,  1.3950876 ,  0.0594182 , -0.569869  ,
#        -2.084373  , -1.1753875 ,  1.1645427 , -1.3566558 , -2.2910738 ,
#         4.6394134 ,  0.5251104 ,  1.4768277 , -1.5296654 , -0.44668978,
#        -5.8846993 ,  0.5518802 , -0.7966353 , -0.6221503 ,  1.0271081 ,
#        -1.3870442 , -2.070831  , -3.2801225 ,  0.5667431 ,  0.61824185,
#        -0.9259353 ,  0.29290083, -0.57024   ,  1.2596213 ,  1.0747768 ,
#         0.11167448,  1.2153887 , -1.3502759 ,  0.35017368, -0.8224534 ,
#         0.7749505 ,  1.1873493 , -1.4996756 , -1.0194116 ,  1.5489638 ,
#         1.3267235 , -1.6505077 , -1.4285718 ,  3.3758514 , -0.5636471 ,
#         2.2849145 ,  2.3317256 ,  1.339602  ,  0.4259996 ,  0.3457305 ,
#        -0.74223846,  2.0267923 ,  2.190265  , -2.0209475 , -0.6847471 ,
#         0.7189782 ,  2.8396344 , -1.6362934 ,  2.2351637 , -2.8194487 ],
#       dtype=float32)

# %%
for n in range(10):
    print("\nThe job is: ", titles[1000*n])
    print("\nTop 5 results:")
    for i in range(5):
        print(" ", i+1, titles[model.docvecs.most_similar(1000*n)[i][0]])
# Out:
# The job is:  "Make It Toxic-Free" Advocate
#
# Top 5 results:
#   1 21st Century Transportation Advocate
#   2 Clean Water Advocate
#   3 Youth Justice Policy Senior Associate
#   4 Senior Program Officer, Program Advocacy and Communications, Global Health Research & Development
#   5 SCL/GDI- Program Coordinator for the Support of Women´s Leadership and Representation (PROLID)- Defined Term Contractual-(DTC)
#
# The job is:  Administrative Coordinator
#
# Top 5 results:
#   1 Administrative Assistant, CMO
#   2 Administrative Assistant
#   3 Executive Assistant
#   4 Executive Assistant
#   5 Office Admin Assistant
#
# The job is:  Brand Specialist - Consumer Electronics
#
# Top 5 results:
#   1 Brand Specialist - Canada Hardlines
#   2 Brand Specialist - Canada Consumables
#   3 Brand Specialist - Canada Hardlines
#   4 Brand Specialist, Grocery
#   5 Vendor Manager
#
# The job is:  Contact Representative (Customer Service Representative)
#
# Top 5 results:
#   1 Contact Representative (Customer Service Representative)
#   2 Contact Representative (Customer Service Representative)
#   3 Contact Representative (Customer Service Representative)
#   4 Customer Service Representative
#   5 Computer Assistant (Hearing Office Systems Administrator)
#
# The job is:  Delivery Contractor
#
# Top 5 results:
#   1 Contract Delivery Driver
#   2 Customer Service Representative
#   3 Route Driver
#   4 Cargo Van Driver-OTR
#   5 Amazon Delivery Driver
#
# The job is:  Executive Office Manager
#
# Top 5 results:
#   1 Executive Office Manager
#   2 Principal Consultant - Construction Claims
#   3 Call Center Team Lead
#   4 Supervisor I, Bankruptcy
#   5 Principal Consultant - Construction Claims
#
# The job is:  Global Noncommunicable Diseases Initiative Intern
#
# Top 5 results:
#   1 Global Noncommunicable Diseases Initiative Intern
#   2 DATA EXTRACTION ANALYST
#   3 DATA EXTRACTION ANALYST
#   4 RESEARCHER, GBD-HIV
#   5 Data Extraction Analyst
#
# The job is:  Job Skills Trainer/Job Coach
#
# Top 5 results:
#   1 Cycle Work Merchandisers for Ongoing Store Resets
#   2 Seattle - Tacoma Metro Area Summer Reading Teacher
#   3 Seattle - Tacoma Metro Area Summer Reading Teacher
#   4 Patient Care Tech/MHW
#   5 Dog Kennel Assistant
#
# The job is:  Medical Assistant/Receptionist - Dallas, TX
#
# Top 5 results:
#   1 Medical Assistant/Receptionist-Orthopedic
#   2 CERTIFIED MEDICAL ASST/RECEPTIONIST FLT - THPG
#   3 Medical Assistant/Receptionist FLT THPG
#   4 Medical Office Receptionist-Fort Worth
#   5 MA/Receptionist or CMA/Receptionist-Float
#
# The job is:  Operations Officer
#
# Top 5 results:
#   1 Lead Contract Specialist
#   2 Geographer, GG-0150-13, Census-DE-TW
#   3 Public Health Analyst
#   4 Security Specialist (Classification)
#   5 Supervisory Survey Specialist, GG-0301-9/11, Census-DE-JMW

# %%
model.wv.most_similar('python')
# Out:
# [('java', 0.5541857481002808),
#  ('c++', 0.49893319606781006),
#  ('stata', 0.4979228377342224),
#  ('cuda', 0.4821644425392151),
#  ('opengl', 0.47420257329940796),
#  ('elasticsearch', 0.4682334065437317),
#  ('bash', 0.46654659509658813),
#  ('angular', 0.455361932516098),
#  ('spss', 0.4511607885360718),
#  ('vba', 0.4499659538269043)]

# %%
model.wv.most_similar('software')
# Out:
# [('wfn', 0.4261420667171478),
#  ('professional', 0.42529863119125366),
#  ('windows-based', 0.4168233871459961),
#  ('parts', 0.4150545299053192),
#  ('windows', 0.41477102041244507),
#  ('java', 0.411377489566803),
#  ('rtos', 0.40638649463653564),
#  ('softwares', 0.4056606888771057),
#  ('technologies', 0.40438976883888245),
#  ('abap', 0.39883822202682495)]

# %%
model.wv.most_similar('communication')
# Out:
# [('communications', 0.7982944846153259),
#  ('communicator', 0.4136987626552582),
#  ('hand-eye', 0.4014595150947571),
#  ('reading/writing', 0.3653428852558136),
#  ('storm', 0.36144858598709106),
#  ('time-management', 0.3601517379283905),
#  ('sudden', 0.357890248298645),
#  ('hd', 0.35413333773612976),
#  ('91st', 0.34989476203918457),
#  ('cutter', 0.3483879566192627)]

# %%
model.wv.most_similar('medical')
# Out:
# [('pediatric', 0.4776403605937958),
#  ('veterinary', 0.4713077247142792),
#  ('kavo', 0.4451991319656372),
#  ('medical/clinical', 0.4440969228744507),
#  ('nonesuch', 0.44075244665145874),
#  ('health', 0.42909711599349976),
#  ('call', 0.4188845157623291),
#  ('chiropractic', 0.414539098739624),
#  ('gorton', 0.4131050705909729),
#  ('medical/dental', 0.4122602045536041)]

# %%
vectors = []
for i in range(len(model.docvecs)-1):
    vectors.append(model.docvecs[i])

# %%
docs_proj = TSNE(random_state=RS).fit_transform(vectors)

# %%
clump = []
def scatter(x):
    # We create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40)
    for i in range(len(vectors)-1):
        if x[i][0] < -30 and x[i][0] > -42 and x[i][1] < -55: 
            ax.annotate(i, (x[i]))
            clump.append(i)
    
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    ax.axis('on')
    ax.axis('tight')
    
    return f, ax, sc

scatter(docs_proj)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11520a860>,
#  <matplotlib.collections.PathCollection at 0x11595e518>)

# %%
for i, index in enumerate(clump):
    print(titles[index])
    print(index)
# Out:
# ADMINISTRATIVE OFFICER
# 162
# ADMINISTRATIVE OFFICER
# 163
# ADMINISTRATIVE SUPPORT ASSISTANT
# 168
# ASSISTANT ADMINISTRATOR, EXTERNAL AFFAIRS/CHIEF OF STAFF
# 203
# Administrative Assistant
# 768
# Administrative Assistant (Office Automation), GS-0303-07 (NTE 6 months)
# 807
# Administrative Assistant, Bureau for Federal Chaplaincy Ministries
# 926
# Administrative Officer
# 1037
# Administrative Officer
# 1038
# Administrative Officer
# 1040
# Administrative Officer, GS-0341-13 (DEU-YBD)
# 1041
# Administrative Support Assistant (Investigations/OA)
# 1089
# Administrative Support Assistant (Investigations/OA)
# 1090
# Administrative Support Assistant (OA)
# 1091
# Air Traffic Control Specialist
# 1174
# Air Traffic Control Specialist (Traffic Management Coordinator)
# 1175
# Airway Transportation Systems Specialist
# 1194
# Animal Keeper (American Trail)
# 1272
# Animal Keeper (American Trail)
# 1273
# Animal Keeper (Primates)
# 1274
# Animal Keeper (Primates)
# 1275
# Animal Keeper - Primates
# 1276
# Appraiser
# 1332
# Appraiser
# 1333
# Assistant General Counsel, EM-0905
# 1484
# Assistant United States Trustee
# 1540
# Assistant United States Trustee
# 1541
# Attorney-Adviser (General), GS-0905-12/13/14 (KD-Exc Svc)
# 1711
# Audiovisual Production Specialist
# 1718
# BUSINESS ANALYST (Management Reporting) CG-501-14
# 1769
# Building Services Worker
# 2018
# CASUALTY ASSISTANCE PROGRAM COORDINATOR
# 2136
# CEO Executive Correspondence Specialist
# 2145
# CIS ASSISTANT (OA)
# 2149
# CRIMINAL INVESTIGATOR
# 2201
# CRIMINAL INVESTIGATOR
# 2202
# Communications Assistant, (Pathways Intern), MC-099-5
# 2804
# Communications and Office Assistant
# 2823
# Computer Assistant (Hearing Office Systems Administrator)
# 2912
# Congressional Affairs Liaison GS-0301-14 (DEU-LL)
# 2952
# Contact Representative (Customer Service Representative)
# 2997
# Contact Representative (Customer Service Representative)
# 2998
# Contact Representative (Customer Service Representative)
# 2999
# Contact Representative (Customer Service Representative)
# 3000
# Contract Administrator
# 3029
# Contract Specialist
# 3037
# Contract Specialist, GS-1102-14
# 3043
# Crime Analyst
# 3268
# Criminal Investigator
# 3276
# Criminal Investigator
# 3277
# Custodial Worker - Direct Hire Authority
# 3311
# Customer Service Representative
# 3542
# DO-0301-01 Administrative Support Specialist
# 3729
# DO-0301-01 Administrative Support Specialist
# 3730
# Deputy Assistant Commissioner, Intelligence
# 4106
# Deputy Assistant Commissioner, Intelligence
# 4107
# Deputy Assistant to the Administrator
# 4108
# Deputy Assistant to the Administrator
# 4109
# Economist (Housing)
# 4474
# Emergency Management Specialist (Geospatial)
# 4541
# Energy Industry Analyst
# 4579
# Energy Industry Analyst (Data Analysis)
# 4580
# Executive Assistant
# 4938
# Executive Assistant
# 4939
# Exhibits Specialist (General)
# 5016
# Financial Assistance
# 5237
# Fish Biologist
# 5273
# Fraud Specialist
# 5400
# Geographer, GG-0150-13, Census-DE-TW
# 5956
# Grants Program Analyst
# 6041
# HUMAN RESOURCES SPECIALIST (MILITARY)
# 6179
# Health Informatics Specialist
# 6236
# Health Insurance Specialist
# 6238
# Horticulturist
# 6331
# Housing Program Assistant
# 6386
# Housing Program Policy Specialist
# 6387
# Human Resources Assistant
# 6427
# Human Resources Assistant
# 6428
# Human Resources Assistant (Recruitment & Placement/Office Automation)
# 6439
# Human Resources Security Specialist
# 6480
# Human Resources Specialist
# 6485
# Human Resources Specialist
# 6492
# Human Resources Specialist (Liaison)
# 6494
# IMMIGRATION SERVICES ASSISTANT (OA)
# 6519
# IMMIGRATION SERVICES OFFICER
# 6520
# INFORMATION TECHNOLOGY SPECIALIST (Security)
# 6521
# INSTRUMENTATION CONTROLS TECHNICIAN
# 6524
# INTELLIGENCE SPECIALIST
# 6526
# INTELLIGENCE SPECIALIST
# 6527
# IT Specialist (INET)
# 6566
# IT Specialist (INFOSEC) (Direct Hire)
# 6567
# IT Specialist (Security)
# 6568
# IT Specialist (Systems Administration)
# 6569
# IT Specialist, GG-2210-07/09/11/12, Census-EXT-JM
# 6571
# Immigration Judge
# 6605
# Immigration Judge
# 6606
# Information Technology Specialist (CUSTSPT)
# 6675
# Intelligence Operations Specialist, GS-0132-13
# 6770
# Interdisciplinary
# 6773
# Interdisciplinary
# 6774
# Interdisciplinary
# 6775
# Intergovernmental Affairs Specialist (National Tribal Affairs Advisor)
# 6776
# International Economist
# 6837
# International Economist
# 6838
# International Trade Specialist
# 6845
# Inventory Management Specialist 054300
# 6915
# Junior Intelligence Analyst - Active Secret or TS required
# 7120
# Land Surveyor
# 7297
# Language Specialist
# 7305
# Language Specialist
# 7306
# Law Clerk (Trainee)
# 7331
# Law Enforcement Officer, GS-1801-15
# 7339
# Lead Contract Specialist
# 7359
# Lead Human Resources Assistant
# 7367
# Legal Assistant (OA) Bilingual
# 7430
# Live Animal Keeper
# 7520
# Logistics Management Specialist
# 7567
# MARINE INTERDICTION AGENT
# 7600
# MASON, WG-3603-11
# 7603
# MISSION SUPPORT ANALYST
# 7622
# MISSION SUPPORT ANALYST
# 7623
# Mail and File Clerk
# 7676
# Mediation Program Coordinator
# 7966
# Military Personnel & Administrative Assistant
# 8330
# Multimedia Production Specialist
# 8367
# Museum Curator (Art) (Head of Product Design & Decorative Arts)
# 8373
# Office Assistant NAS Executive Office
# 8687
# Office Automation Assistant (Records Disclosure)
# 8719
# Office of The Clerk (Wounded Warrior Fellowship Program)
# 8896
# Officer (Uniformed Division)
# 8905
# Operations Officer
# 9000
# Operations Research Analyst
# 9012
# Operations Research Analyst
# 9013
# PAINTER
# 9134
# PAINTER-DECORATOR
# 9135
# PUBLIC AFFAIRS SPECIALIST
# 9230
# PURCHASING AGENT
# 9234
# Park Ranger
# 9314
# Park Ranger
# 9315
# Personnel Liaison Specialist
# 9888
# Pipefitter
# 9947
# Policy Analyst
# 9986
# Policy Analyst
# 9987
# Policy Analyst
# 9988
# Probation Administrator
# 10097
# Probation Administrator
# 10098
# Probation Administrator (Information Systems)
# 10100
# Program Analyst
# 10288
# Program Analyst
# 10289
# Program Analyst
# 10290
# Program Assistant
# 10307
# Program Assistant [Kennan Institute]
# 10320
# Program Assistant [Kennan Institute]
# 10321
# Program Officer (MN)
# 10412
# Program Officer (MN)
# 10413
# Program Specialist - Administrative Assistant
# 10417
# Program Specialist, CG-0301-12/13
# 10435
# Program Support Specialist
# 10440
# Project Resource Analyst
# 10500
# Public Affairs Specialist
# 10545
# Public Health Analyst
# 10552
# Public Health Analyst
# 10553
# Records Management Assistant, GS-0303-06, Census-DE-CH
# 11108
# Recruiting Coordinator, GG-0301-13, Census-EXT-KTE
# 11150
# SR IT SPECIALIST (SECURITY), CG-2210-14
# 11577
# SUPERVISORY IMMIGRATION ANALYST (ASYLUM)
# 11592
# SUPERVISORY IMMIGRATION ANALYST (ASYLUM)
# 11593
# Safety and Occupational Health Specialist
# 11608
# Safety and Occupational Health Specialist
# 11609
# Secretary
# 11810
# Secretary (OA)
# 11814
# Secretary (OA)
# 11815
# Security Assistant - DE
# 11837
# Security Assistant - DE
# 11838
# Security Guard
# 11846
# Security Specialist
# 11890
# Security Specialist (Classification)
# 11891
# Space Leasing Coordinator, GG-0301-13, Census-EXT-KTE
# 12497
# Space Leasing Representative, GG-0301-07/09/11/12, Census-EXT-KTE
# 12498
# Special Assistant to the IG
# 12517
# Special Assistant to the IG
# 12518
# Staff Assistant
# 12569
# Staff Assistant
# 12572
# Student Trainee (Auditing)
# 12759
# Supervisory Attorney-Adviser (General), GS-0905-15 (KD-Exc Svc)
# 12838
# Supervisory Information Technology Specialist (Enterprise Architecture)
# 12839
# Supervisory Information Technology Specialist (InfoSec) (DHA)
# 12840
# Supervisory Recruitment & Placement Specialist
# 12841
# Supervisory Survey Specialist, GG-0301-9/11, Census-DE-JMW
# 12843
# Survey Statistician, GG-1530-13, Census-DE-TW
# 12895
# Time and Leave Clerk (OA)
# 13189
# Training Administrator
# 13227
# Training Specialist
# 13242
# Transportation Assistant
# 13263
# Transportation Security Officer (TSO)
# 13271
# Utility Systems Repairer-Operator Leader
# 13429
# Veterans Service Representative (Rating)
# 13520
# Visual Information Specialist
# 13596
